# %%
import pandas as pd

df = pd.read_csv('GOOG.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2004-08-19    2.490664    2.591785    2.390042    2.499133    2.496292
# 1     2004-08-20    2.515820    2.716817    2.503118    2.697639    2.694573
# 2     2004-08-23    2.758411    2.826406    2.716070    2.724787    2.721690
# 3     2004-08-24    2.770615    2.779581    2.579581    2.611960    2.608991
# 4     2004-08-25    2.614201    2.689918    2.587302    2.640104    2.637103
# ...          ...         ...         ...         ...         ...         ...
# 4989  2024-06-14  175.852005  178.729996  175.852005  178.369995  178.369995
# 4990  2024-06-17  176.979996  179.919998  176.490005  178.779999  178.779999
# 4991  2024-06-18  178.789993  178.910004  175.619995  176.449997  176.449997
# 4992  2024-06-20  176.710007  178.740005  176.460007  177.710007  177.710007
# 4993  2024-06-21  178.490005  182.511993  178.059998  180.259995  180.259995
#
#          Volume
# 0     897427216
# 1     458857488
# 2     366857939
# 3     306396159
# 4     184645512
# ...         ...
# 4989   12361600
# 4990   15272900
# 4991   15640300
# 4992   16753200
# 4993   58903200
#
# [4994 rows x 7 columns]

# %%
df = df[['Date','Close']]
df
# Out:
#             Date       Close
# 0     2004-08-19    2.499133
# 1     2004-08-20    2.697639
# 2     2004-08-23    2.724787
# 3     2004-08-24    2.611960
# 4     2004-08-25    2.640104
# ...          ...         ...
# 4989  2024-06-14  178.369995
# 4990  2024-06-17  178.779999
# 4991  2024-06-18  176.449997
# 4992  2024-06-20  177.710007
# 4993  2024-06-21  180.259995
#
# [4994 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       2004-08-19
# 1       2004-08-20
# 2       2004-08-23
# 3       2004-08-24
# 4       2004-08-25
#            ...
# 4989    2024-06-14
# 4990    2024-06-17
# 4991    2024-06-18
# 4992    2024-06-20
# 4993    2024-06-21
# Name: Date, Length: 4994, dtype: object

# %%
import datetime
def str_to_datetime(s):
    split = s.split('-')
    year,month,day = int(split[0]),int(split[1]),int(split[2])
    return datetime.datetime(year=year,month=month,day=day)
datetime_object = str_to_datetime('2015-12-19')
datetime_object
# Out:
# datetime.datetime(2015, 12, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     2004-08-19    2.499133
# 1     2004-08-20    2.697639
# 2     2004-08-23    2.724787
# 3     2004-08-24    2.611960
# 4     2004-08-25    2.640104
# ...          ...         ...
# 4989  2024-06-14  178.369995
# 4990  2024-06-17  178.779999
# 4991  2024-06-18  176.449997
# 4992  2024-06-20  177.710007
# 4993  2024-06-21  180.259995
#
# [4994 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# /var/folders/cl/_mrsr8817s777xthg06v1mwh0000gn/T/ipykernel_51785/2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      2004-08-19
# 1      2004-08-20
# 2      2004-08-23
# 3      2004-08-24
# 4      2004-08-25
#           ...
# 4989   2024-06-14
# 4990   2024-06-17
# 4991   2024-06-18
# 4992   2024-06-20
# 4993   2024-06-21
# Name: Date, Length: 4994, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 2004-08-19    2.499133
# 2004-08-20    2.697639
# 2004-08-23    2.724787
# 2004-08-24    2.611960
# 2004-08-25    2.640104
# ...                ...
# 2024-06-14  178.369995
# 2024-06-17  178.779999
# 2024-06-18  176.449997
# 2024-06-20  177.710007
# 2024-06-21  180.259995
#
# [4994 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df.index,df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, f_date_str, l_date_str,n=3):
    f_date = str_to_datetime(f_date_str)
    l_date = str_to_datetime(l_date_str)
    target_date = f_date

    dates = []
    X,Y = [],[]
    l_time = False
    while True:
        df_subset = dataframe.loc[:target_date].tail(n+1)

        if len(df_subset) != n+1:
            print(f'Error: Window of size {n} is too larget for date {target_date}')
            return
        values = df_subset['Close'].to_numpy()
        x,y=values[:-1],values[-1]

        dates.append(target_date)
        X.append(x)
        Y.append(y)
        next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
        next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
        next_date_str = next_datetime_str.split('T')[0]
        year_month_day = next_date_str.split('-')
        year, month, day = year_month_day
        next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
        if l_time:
          break
        target_date = next_date
        if target_date == l_date:
            l_time=True
    ret_df = pd.DataFrame({})
    ret_df['Target Date'] = dates
    X = np.array(X)
    for i in range(0,n):
        X[:,i]
        ret_df[f'Target-{n-i}'] = X[:,i]
    ret_df['Target'] = Y
    return ret_df

windowed_df = df_to_windowed_df(df, 
                                '2021-02-01', 
                                '2024-03-13', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-02-01   91.539497   93.155502   91.787003   95.067497
# 1    2021-02-02   93.155502   91.787003   95.067497   96.375504
# 2    2021-02-03   91.787003   95.067497   96.375504  103.503502
# 3    2021-02-04   95.067497   96.375504  103.503502  103.118500
# 4    2021-02-05   96.375504  103.503502  103.118500  104.900002
# ..          ...         ...         ...         ...         ...
# 779  2024-03-07  134.199997  133.779999  132.559998  135.240005
# 780  2024-03-08  133.779999  132.559998  135.240005  136.289993
# 781  2024-03-11  132.559998  135.240005  136.289993  138.940002
# 782  2024-03-12  135.240005  136.289993  138.940002  139.619995
# 783  2024-03-13  136.289993  138.940002  139.619995  140.770004
#
# [784 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((784,), (784, 3, 1), (784,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 2024-06-23 19:19:36.111492: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 14151.6904 - mean_absolute_error: 117.7181 - val_loss: 17664.0703 - val_mean_absolute_error: 132.8344
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 14054.1240 - mean_absolute_error: 117.2820 - val_loss: 17245.2930 - val_mean_absolute_error: 131.2486
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13761.9980 - mean_absolute_error: 116.0232 - val_loss: 16330.9189 - val_mean_absolute_error: 127.7174
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 12440.8008 - mean_absolute_error: 110.1377 - val_loss: 13845.8828 - val_mean_absolute_error: 117.5858
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9940.9199 - mean_absolute_error: 98.1796 - val_loss: 9907.0322 - val_mean_absolute_error: 99.4336
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6232.3999 - mean_absolute_error: 76.7506 - val_loss: 4924.9629 - val_mean_absolute_error: 70.0381
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2522.2332 - mean_absolute_error: 46.2689 - val_loss: 1362.9027 - val_mean_absolute_error: 36.6559
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 565.2845 - mean_absolute_error: 19.2181 - val_loss: 209.6177 - val_mean_absolute_error: 13.8005
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 311.3413 - mean_absolute_error: 14.9721 - val_loss: 217.0219 - val_mean_absolute_error: 14.0984
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 269.3769 - mean_absolute_error: 14.1336 - val_loss: 220.3677 - val_mean_absolute_error: 14.3095
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 221.7138 - mean_absolute_error: 12.6944 - val_loss: 151.9825 - val_mean_absolute_error: 11.7416
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 168.9771 - mean_absolute_error: 10.8386 - val_loss: 92.8911 - val_mean_absolute_error: 8.8957
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 135.0520 - mean_absolute_error: 9.7620 - val_loss: 57.2718 - val_mean_absolute_error: 6.8377
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 69.3398 - mean_absolute_error: 6.5562 - val_loss: 27.1948 - val_mean_absolute_error: 4.5105
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 30.0837 - mean_absolute_error: 4.0592 - val_loss: 12.6315 - val_mean_absolute_error: 2.9886
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 16.0238 - mean_absolute_error: 3.1070 - val_loss: 5.6986 - val_mean_absolute_error: 1.7804
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 12.5938 - mean_absolute_error: 2.7595 - val_loss: 8.6303 - val_mean_absolute_error: 2.1162
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.2020 - mean_absolute_error: 2.5835 - val_loss: 6.7655 - val_mean_absolute_error: 1.7555
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.6149 - mean_absolute_error: 2.1259 - val_loss: 5.4403 - val_mean_absolute_error: 1.6774
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4483 - mean_absolute_error: 2.1097 - val_loss: 6.4892 - val_mean_absolute_error: 1.6931
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3486 - mean_absolute_error: 1.9797 - val_loss: 5.8260 - val_mean_absolute_error: 1.5877
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3010 - mean_absolute_error: 1.9385 - val_loss: 5.4410 - val_mean_absolute_error: 1.5886
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7126 - mean_absolute_error: 2.0236 - val_loss: 6.0299 - val_mean_absolute_error: 1.8392
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4173 - mean_absolute_error: 1.9545 - val_loss: 5.9992 - val_mean_absolute_error: 1.6151
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9105 - mean_absolute_error: 1.8257 - val_loss: 6.2669 - val_mean_absolute_error: 1.6535
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3568 - mean_absolute_error: 1.9796 - val_loss: 5.4905 - val_mean_absolute_error: 1.5874
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8495 - mean_absolute_error: 1.8769 - val_loss: 6.4483 - val_mean_absolute_error: 1.6787
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1608 - mean_absolute_error: 1.8591 - val_loss: 6.0919 - val_mean_absolute_error: 1.8438
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4710 - mean_absolute_error: 1.9584 - val_loss: 6.0139 - val_mean_absolute_error: 1.6223
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0489 - mean_absolute_error: 2.0499 - val_loss: 6.8337 - val_mean_absolute_error: 1.7501
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0267 - mean_absolute_error: 1.8567 - val_loss: 5.7980 - val_mean_absolute_error: 1.5954
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5334 - mean_absolute_error: 2.0008 - val_loss: 10.3517 - val_mean_absolute_error: 2.3778
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4361 - mean_absolute_error: 1.9531 - val_loss: 6.7004 - val_mean_absolute_error: 1.7248
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.1742 - mean_absolute_error: 1.8815 - val_loss: 5.6010 - val_mean_absolute_error: 1.5950
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8566 - mean_absolute_error: 1.8223 - val_loss: 6.8775 - val_mean_absolute_error: 1.7584
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.7785 - mean_absolute_error: 2.1087 - val_loss: 7.2885 - val_mean_absolute_error: 1.8331
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7344 - mean_absolute_error: 1.9939 - val_loss: 10.8823 - val_mean_absolute_error: 2.4665
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9075 - mean_absolute_error: 2.1740 - val_loss: 6.4787 - val_mean_absolute_error: 1.6864
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.9198 - mean_absolute_error: 2.0162 - val_loss: 5.8446 - val_mean_absolute_error: 1.7464
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0195 - mean_absolute_error: 2.0170 - val_loss: 5.5580 - val_mean_absolute_error: 1.6400
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9766 - mean_absolute_error: 1.9619 - val_loss: 6.2116 - val_mean_absolute_error: 1.6436
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4601 - mean_absolute_error: 1.8398 - val_loss: 8.2961 - val_mean_absolute_error: 2.0110
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0213 - mean_absolute_error: 1.8820 - val_loss: 6.2851 - val_mean_absolute_error: 1.6604
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7509 - mean_absolute_error: 1.8261 - val_loss: 5.5411 - val_mean_absolute_error: 1.6087
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9172 - mean_absolute_error: 1.7932 - val_loss: 5.6396 - val_mean_absolute_error: 1.5954
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4913 - mean_absolute_error: 1.9317 - val_loss: 5.7302 - val_mean_absolute_error: 1.5887
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2801 - mean_absolute_error: 1.9295 - val_loss: 8.5636 - val_mean_absolute_error: 2.0552
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5007 - mean_absolute_error: 1.9166 - val_loss: 9.8126 - val_mean_absolute_error: 2.2852
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0768 - mean_absolute_error: 2.0506 - val_loss: 5.6692 - val_mean_absolute_error: 1.7146
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4381 - mean_absolute_error: 1.7549 - val_loss: 6.0556 - val_mean_absolute_error: 1.6297
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0962 - mean_absolute_error: 1.8714 - val_loss: 5.5946 - val_mean_absolute_error: 1.6104
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9753 - mean_absolute_error: 1.8749 - val_loss: 5.3388 - val_mean_absolute_error: 1.5792
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2720 - mean_absolute_error: 1.9348 - val_loss: 5.5413 - val_mean_absolute_error: 1.6044
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8374 - mean_absolute_error: 1.8288 - val_loss: 6.8127 - val_mean_absolute_error: 1.7503
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2916 - mean_absolute_error: 1.9215 - val_loss: 6.0362 - val_mean_absolute_error: 1.8531
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8730 - mean_absolute_error: 1.8737 - val_loss: 6.3083 - val_mean_absolute_error: 1.6596
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2485 - mean_absolute_error: 1.8778 - val_loss: 5.8474 - val_mean_absolute_error: 1.7587
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5826 - mean_absolute_error: 1.8209 - val_loss: 6.7401 - val_mean_absolute_error: 1.7368
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.1903 - mean_absolute_error: 1.6857 - val_loss: 5.7479 - val_mean_absolute_error: 1.5971
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7618 - mean_absolute_error: 1.8469 - val_loss: 6.0721 - val_mean_absolute_error: 1.6234
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4782 - mean_absolute_error: 1.8214 - val_loss: 5.9957 - val_mean_absolute_error: 1.6270
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6362 - mean_absolute_error: 1.7879 - val_loss: 6.7281 - val_mean_absolute_error: 2.0006
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8272 - mean_absolute_error: 1.8853 - val_loss: 9.0128 - val_mean_absolute_error: 2.4696
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4676 - mean_absolute_error: 1.9726 - val_loss: 6.0618 - val_mean_absolute_error: 1.6359
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3332 - mean_absolute_error: 1.7678 - val_loss: 5.7423 - val_mean_absolute_error: 1.7555
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6023 - mean_absolute_error: 1.7982 - val_loss: 10.5457 - val_mean_absolute_error: 2.4041
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.7771 - mean_absolute_error: 2.0176 - val_loss: 5.9435 - val_mean_absolute_error: 1.7686
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1182 - mean_absolute_error: 2.0537 - val_loss: 5.4925 - val_mean_absolute_error: 1.5734
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.3882 - mean_absolute_error: 2.0758 - val_loss: 5.9073 - val_mean_absolute_error: 1.6205
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8105 - mean_absolute_error: 1.8330 - val_loss: 5.5820 - val_mean_absolute_error: 1.6533
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.2265 - mean_absolute_error: 1.6686 - val_loss: 5.5525 - val_mean_absolute_error: 1.6293
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1916 - mean_absolute_error: 1.8791 - val_loss: 5.5466 - val_mean_absolute_error: 1.6282
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6273 - mean_absolute_error: 1.9521 - val_loss: 8.1880 - val_mean_absolute_error: 2.3164
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6517 - mean_absolute_error: 2.0078 - val_loss: 6.4000 - val_mean_absolute_error: 1.6783
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3083 - mean_absolute_error: 1.8988 - val_loss: 5.7884 - val_mean_absolute_error: 1.5945
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4005 - mean_absolute_error: 1.9307 - val_loss: 5.7428 - val_mean_absolute_error: 1.5975
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8730 - mean_absolute_error: 1.8377 - val_loss: 6.0698 - val_mean_absolute_error: 1.6313
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1502 - mean_absolute_error: 1.8816 - val_loss: 6.1024 - val_mean_absolute_error: 1.8569
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4285 - mean_absolute_error: 1.7906 - val_loss: 5.6057 - val_mean_absolute_error: 1.6930
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0039 - mean_absolute_error: 1.8085 - val_loss: 5.9113 - val_mean_absolute_error: 1.6288
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4738 - mean_absolute_error: 1.7936 - val_loss: 5.4529 - val_mean_absolute_error: 1.6134
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7039 - mean_absolute_error: 1.8398 - val_loss: 5.4553 - val_mean_absolute_error: 1.5974
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.1123 - mean_absolute_error: 1.6926 - val_loss: 6.7387 - val_mean_absolute_error: 2.0028
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4277 - mean_absolute_error: 2.1044 - val_loss: 7.3094 - val_mean_absolute_error: 1.8326
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8541 - mean_absolute_error: 1.8202 - val_loss: 5.8639 - val_mean_absolute_error: 1.6096
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4099 - mean_absolute_error: 1.7657 - val_loss: 5.8722 - val_mean_absolute_error: 1.7964
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2987 - mean_absolute_error: 1.8692 - val_loss: 6.1912 - val_mean_absolute_error: 1.8758
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5548 - mean_absolute_error: 1.9207 - val_loss: 6.3551 - val_mean_absolute_error: 1.6709
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3072 - mean_absolute_error: 1.7601 - val_loss: 5.4519 - val_mean_absolute_error: 1.6105
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3306 - mean_absolute_error: 1.7590 - val_loss: 6.2409 - val_mean_absolute_error: 1.6474
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7465 - mean_absolute_error: 1.7902 - val_loss: 8.1604 - val_mean_absolute_error: 1.9956
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0050 - mean_absolute_error: 2.0267 - val_loss: 5.8258 - val_mean_absolute_error: 1.6034
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3357 - mean_absolute_error: 1.7008 - val_loss: 6.0021 - val_mean_absolute_error: 1.8268
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.7716 - mean_absolute_error: 1.7899 - val_loss: 6.4984 - val_mean_absolute_error: 1.6946
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4604 - mean_absolute_error: 1.9066 - val_loss: 8.9209 - val_mean_absolute_error: 2.4616
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.3475 - mean_absolute_error: 1.9439 - val_loss: 6.2396 - val_mean_absolute_error: 1.6564
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2980 - mean_absolute_error: 1.7337 - val_loss: 6.4666 - val_mean_absolute_error: 1.9485
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2424 - mean_absolute_error: 1.9308 - val_loss: 6.1807 - val_mean_absolute_error: 1.6504
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8686 - mean_absolute_error: 1.8296 - val_loss: 6.2595 - val_mean_absolute_error: 1.8986
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4876 - mean_absolute_error: 1.7947 - val_loss: 5.5055 - val_mean_absolute_error: 1.5934

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
